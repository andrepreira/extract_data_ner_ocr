# %%
import numpy as np
import pandas as pd
import cv2
import pytesseract
from glob import glob
import spacy
import re
import string
import PIL

# %%
def cleanText(txt):
    whitespace = string.whitespace
    punctuation = "!#$%&\'()*+:;<=>?[\\]^`{|}~"
    tableWhiteSpace = str.maketrans('','',whitespace)
    tablePunctuation = str.maketrans('','',punctuation)
    text = str(txt)
    text = text.lower()
    removewhitespace = text.translate(tableWhiteSpace)
    removepunctuation = removewhitespace.translate(tablePunctuation)
    
    return str(removepunctuation)

# %%
## Load NER model

model_ner = spacy.load('./output/model-best/')

# %%
model_ner

# %%
# Load Image

image = cv2.imread('./data/6.jpg')

# extract data using Pytesseract
tessData = pytesseract.image_to_data(image)

# convert into dataframe
tessList = list(map(lambda x: x.split('\t'), tessData.split('\n')))
df = pd.DataFrame(tessList[1:], columns=tessList[0])
df.dropna(inplace=True) # drop missing values
df['text'] = df['text'].apply(cleanText)

# convert data into content

df_clean = df.query('text !="" ')
content = " ".join([w for w in df_clean['text']])

# get prediction from NER model
doc = model_ner(content)

# %%
content
# Out:
# 'cell 8099948528 te 8466045457 email lictsrikant@gmail.com life insurance corporation of india seosrikantht@gmail.com thathineni srikanth insurance advisor agent code no. 0316164y life insurance corporation of india br. off. lic office, trimulgherry, sec’bad - 500 016. add. borabanda, hyderabad - 500 018. lictsrikant8099948528.blogspot.in, interviewsinhyderabad.blogspot.in facebook.com/lictsrikant8099948528, facebook.com/thathineni.srikanth.9 promote your business online pybo'

# %%
from spacy import displacy

# %%
displacy.render(doc, style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">cell
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     8099948528
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-PHONE</span>
# </mark>
#  te
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     8466045457
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-PHONE</span>
# </mark>
#  email
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     lictsrikant@gmail.com
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-EMAIL</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     life
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-ORG</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     insurance
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-ORG</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     corporation
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-ORG</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     of
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-ORG</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     india
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-ORG</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     seosrikantht@gmail.com
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-EMAIL</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     thathineni
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-NAME</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     srikanth
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-NAME</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     insurance
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-DES</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     advisor
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-DES</span>
# </mark>
#  agent code no. 0316164y
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     life
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-ORG</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     insurance
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-ORG</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     corporation
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-ORG</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     of
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-ORG</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     india
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-ORG</span>
# </mark>
#  br. off. lic office, trimulgherry, sec’bad - 500 016. add. borabanda, hyderabad - 500 018.
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     lictsrikant8099948528.blogspot.in
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-WEB</span>
# </mark>
# ,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     interviewsinhyderabad.blogspot.in
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-WEB</span>
# </mark>
#  facebook.com/lictsrikant8099948528, facebook.com/thathineni.srikanth.9 promote your business online pybo</div></span>

# %% [markdown]
# ## Tagging

# %%
docjson = doc.to_json()
docjson.keys()
# Out:
# dict_keys(['text', 'ents', 'tokens'])

# %%
docjson['text']
# Out:
# 'cell 8099948528 te 8466045457 email lictsrikant@gmail.com life insurance corporation of india seosrikantht@gmail.com thathineni srikanth insurance advisor agent code no. 0316164y life insurance corporation of india br. off. lic office, trimulgherry, sec’bad - 500 016. add. borabanda, hyderabad - 500 018. lictsrikant8099948528.blogspot.in, interviewsinhyderabad.blogspot.in facebook.com/lictsrikant8099948528, facebook.com/thathineni.srikanth.9 promote your business online pybo'

# %%
doc_text = docjson['text']

# %%
dataframe_tokens = pd.DataFrame(docjson['tokens'])
dataframe_tokens['token'] = dataframe_tokens[['start', 'end']].apply(
    lambda x:doc_text[x[0]:x[1]], axis= 1
)

# %%
right_table = pd.DataFrame(docjson['ents'])[['start', 'label']]
dataframe_tokens = pd.merge(dataframe_tokens, right_table, how='left', on='start')
dataframe_tokens.fillna('O', inplace=True)

# %%
dataframe_tokens
# Out:
#     id  start  end                               token    label
# 0    0      0    4                                cell        O
# 1    1      5   15                          8099948528  B-PHONE
# 2    2     16   18                                  te        O
# 3    3     19   29                          8466045457  B-PHONE
# 4    4     30   35                               email        O
# 5    5     36   57               lictsrikant@gmail.com  B-EMAIL
# 6    6     58   62                                life    B-ORG
# 7    7     63   72                           insurance    I-ORG
# 8    8     73   84                         corporation    I-ORG
# 9    9     85   87                                  of    I-ORG
# 10  10     88   93                               india    I-ORG
# 11  11     94  116              seosrikantht@gmail.com  B-EMAIL
# 12  12    117  127                          thathineni   B-NAME
# 13  13    128  136                            srikanth   I-NAME
# 14  14    137  146                           insurance    B-DES
# 15  15    147  154                             advisor    I-DES
# 16  16    155  160                               agent        O
# 17  17    161  165                                code        O
# 18  18    166  168                                  no        O
# 19  19    168  169                                   .        O
# 20  20    170  178                            0316164y        O
# 21  21    179  183                                life    B-ORG
# 22  22    184  193                           insurance    I-ORG
# 23  23    194  205                         corporation    I-ORG
# 24  24    206  208                                  of    I-ORG
# 25  25    209  214                               india    I-ORG
# 26  26    215  217                                  br        O
# 27  27    217  218                                   .        O
# 28  28    219  222                                 off        O
# 29  29    222  223                                   .        O
# 30  30    224  227                                 lic        O
# 31  31    228  234                              office        O
# 32  32    234  235                                   ,        O
# 33  33    236  248                        trimulgherry        O
# 34  34    248  249                                   ,        O
# 35  35    250  257                             sec’bad        O
# 36  36    258  259                                   -        O
# 37  37    260  263                                 500        O
# 38  38    264  267                                 016        O
# 39  39    267  268                                   .        O
# 40  40    269  272                                 add        O
# 41  41    272  273                                   .        O
# 42  42    274  283                           borabanda        O
# 43  43    283  284                                   ,        O
# 44  44    285  294                           hyderabad        O
# 45  45    295  296                                   -        O
# 46  46    297  300                                 500        O
# 47  47    301  304                                 018        O
# 48  48    304  305                                   .        O
# 49  49    306  339   lictsrikant8099948528.blogspot.in    B-WEB
# 50  50    339  340                                   ,        O
# 51  51    341  374   interviewsinhyderabad.blogspot.in    B-WEB
# 52  52    375  409  facebook.com/lictsrikant8099948528        O
# 53  53    409  410                                   ,        O
# 54  54    411  445  facebook.com/thathineni.srikanth.9        O
# 55  55    446  453                             promote        O
# 56  56    454  458                                your        O
# 57  57    459  467                            business        O
# 58  58    468  474                              online        O
# 59  59    475  479                                pybo        O

# %%
# join label to df_clean dataframe
df_clean['end'] = df_clean['text'].apply(lambda x: len(x)+1).cumsum() -1
df_clean['start'] = df_clean[['text', 'end']].apply(lambda x: x[1] - len(x[0]), axis=1)
# Out:
# /tmp/ipykernel_2372/3182064150.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['end'] = df_clean['text'].apply(lambda x: len(x)+1).cumsum() -1
# /tmp/ipykernel_2372/3182064150.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['start'] = df_clean[['text', 'end']].apply(lambda x: x[1] - len(x[0]), axis=1)

# %%
# inner join with start

dataframe_info = pd.merge(df_clean, dataframe_tokens[['start', 'token', 'label']], how='inner',on='start')

# %%
dataframe_info.tail(10)
# Out:
#    level page_num block_num par_num line_num word_num left  top width height  \
# 39     5        1         6       3        1        6  495  474    53     21
# 40     5        1         6       3        2        1   46  506   430     27
# 41     5        1         6       3        2        2  488  506   429     27
# 42     5        1         6       3        3        1   44  539   472     25
# 43     5        1         6       3        3        2  526  539   443     22
# 44     5        1         6       3        4        1   46  571   106     21
# 45     5        1         6       3        4        2  161  576    56     22
# 46     5        1         6       3        4        3  226  571   111     21
# 47     5        1         6       3        4        4  347  571    74     21
# 48     5        1         6       3        4        5  432  571    96     27
#
#    conf                                 text  end  start  \
# 39   95                                 018.  305    301
# 40   86   lictsrikant8099948528.blogspot.in,  340    306
# 41   86    interviewsinhyderabad.blogspot.in  374    341
# 42   90  facebook.com/lictsrikant8099948528,  410    375
# 43   90   facebook.com/thathineni.srikanth.9  445    411
# 44   96                              promote  453    446
# 45   96                                 your  458    454
# 46   96                             business  467    459
# 47   92                               online  474    468
# 48   92                                 pybo  479    475
#
#                                  token  label
# 39                                 018      O
# 40   lictsrikant8099948528.blogspot.in  B-WEB
# 41   interviewsinhyderabad.blogspot.in  B-WEB
# 42  facebook.com/lictsrikant8099948528      O
# 43  facebook.com/thathineni.srikanth.9      O
# 44                             promote      O
# 45                                your      O
# 46                            business      O
# 47                              online      O
# 48                                pybo      O

# %% [markdown]
# ## Bounding Box

# %%
bb_df = dataframe_info.query("label != 'O' ")
img = image.copy()

for x,y,w,h,label in bb_df[['left', 'top', 'width', 'height', 'label']].values:
    x = int(x)    
    y = int(y)
    w = int(w)
    h = int(h)
    
    cv2.rectangle(img, (x,y), (x+w,x+h),(0,255,0),2)
    cv2.putText(img,str(label),(x,y),cv2.FONT_HERSHEY_PLAIN,1,(0,0,255),2)

PIL.Image.fromarray(img)
# Out:
# <PIL.Image.Image image mode=RGB size=1065x616>

# %%
bb_df['label'] = bb_df['label'].apply(lambda x: x[2:])
bb_df
# Out:
# /tmp/ipykernel_2372/14576741.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bb_df['label'] = bb_df['label'].apply(lambda x: x[2:])
#    level page_num block_num par_num line_num word_num left  top width height  \
# 1      5        1         3       1        1        3  822   53   203     28
# 3      5        1         3       2        1        2  822   71   197     67
# 5      5        1         3       2        2        3  709  136   316     31
# 6      5        1         3       3        1        1   46  170    33     14
# 7      5        1         3       3        1        2   85  151    91     42
# 8      5        1         3       3        1        3  183  170   117     14
# 9      5        1         3       3        1        4  306  170    20     14
# 10     5        1         3       3        1        5  332  170    42     14
# 11     5        1         3       3        1        6  668  163   357     46
# 12     5        1         4       1        1        1  310  228   232     30
# 13     5        1         4       1        1        2  557  227   198     32
# 14     5        1         5       1        1        1  399  271   147     25
# 15     5        1         5       1        1        2  555  271   114     25
# 20     5        1         6       1        1        1   47  396    83     30
# 21     5        1         6       1        1        2  145  395   236     32
# 22     5        1         6       1        1        3  395  395   296     32
# 23     5        1         6       1        1        4  706  395    53     32
# 24     5        1         6       1        1        5  775  396   107     30
# 40     5        1         6       3        2        1   46  506   430     27
# 41     5        1         6       3        2        2  488  506   429     27
#
#    conf                                text  end  start  \
# 1    96                          8099948528   15      5
# 3    94                          8466045457   29     19
# 5    88               lictsrikant@gmail.com   57     36
# 6    96                                life   62     58
# 7    94                           insurance   72     63
# 8    96                         corporation   84     73
# 9    96                                  of   87     85
# 10   96                               india   93     88
# 11   91              seosrikantht@gmail.com  116     94
# 12   92                          thathineni  127    117
# 13   96                            srikanth  136    128
# 14   96                           insurance  146    137
# 15   96                             advisor  154    147
# 20   96                                life  183    179
# 21   96                           insurance  193    184
# 22   96                         corporation  205    194
# 23   94                                  of  208    206
# 24   94                               india  214    209
# 40   86  lictsrikant8099948528.blogspot.in,  340    306
# 41   86   interviewsinhyderabad.blogspot.in  374    341
#
#                                 token  label
# 1                          8099948528  PHONE
# 3                          8466045457  PHONE
# 5               lictsrikant@gmail.com  EMAIL
# 6                                life    ORG
# 7                           insurance    ORG
# 8                         corporation    ORG
# 9                                  of    ORG
# 10                              india    ORG
# 11             seosrikantht@gmail.com  EMAIL
# 12                         thathineni   NAME
# 13                           srikanth   NAME
# 14                          insurance    DES
# 15                            advisor    DES
# 20                               life    ORG
# 21                          insurance    ORG
# 22                        corporation    ORG
# 23                                 of    ORG
# 24                              india    ORG
# 40  lictsrikant8099948528.blogspot.in    WEB
# 41  interviewsinhyderabad.blogspot.in    WEB

# %%
# group the labels

class groupgen():
    def __init__(self):
        self.id = 0
        self.text = ''
    
    def getgroup(self,text):
        if self.text == text:
            return self.id
        else:
            self.id +=1
            self.text = text
            return self.id

grp_gen = groupgen()

# %%
bb_df['group'] = bb_df['label'].apply(grp_gen.getgroup)
# Out:
# /tmp/ipykernel_2372/472836701.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bb_df['group'] = bb_df['label'].apply(grp_gen.getgroup)

# %%
# right and bottom of bounding box

bb_df[['left', 'top', 'width', 'height']] = bb_df[['left', 'top', 'width', 'height']].astype(int)
bb_df['right'] = bb_df['left'] + bb_df['width']
bb_df['bottom'] = bb_df['top'] + bb_df['height']
# Out:
# /tmp/ipykernel_2372/722450050.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bb_df[['left', 'top', 'width', 'height']] = bb_df[['left', 'top', 'width', 'height']].astype(int)
# /tmp/ipykernel_2372/722450050.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bb_df['right'] = bb_df['left'] + bb_df['width']
# /tmp/ipykernel_2372/722450050.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bb_df['bottom'] = bb_df['top'] + bb_df['height']

# %%
bb_df
# Out:
#    level page_num block_num par_num line_num word_num  left  top  width  \
# 1      5        1         3       1        1        3   822   53    203
# 3      5        1         3       2        1        2   822   71    197
# 5      5        1         3       2        2        3   709  136    316
# 6      5        1         3       3        1        1    46  170     33
# 7      5        1         3       3        1        2    85  151     91
# 8      5        1         3       3        1        3   183  170    117
# 9      5        1         3       3        1        4   306  170     20
# 10     5        1         3       3        1        5   332  170     42
# 11     5        1         3       3        1        6   668  163    357
# 12     5        1         4       1        1        1   310  228    232
# 13     5        1         4       1        1        2   557  227    198
# 14     5        1         5       1        1        1   399  271    147
# 15     5        1         5       1        1        2   555  271    114
# 20     5        1         6       1        1        1    47  396     83
# 21     5        1         6       1        1        2   145  395    236
# 22     5        1         6       1        1        3   395  395    296
# 23     5        1         6       1        1        4   706  395     53
# 24     5        1         6       1        1        5   775  396    107
# 40     5        1         6       3        2        1    46  506    430
# 41     5        1         6       3        2        2   488  506    429
#
#     height conf                                text  end  start  \
# 1       28   96                          8099948528   15      5
# 3       67   94                          8466045457   29     19
# 5       31   88               lictsrikant@gmail.com   57     36
# 6       14   96                                life   62     58
# 7       42   94                           insurance   72     63
# 8       14   96                         corporation   84     73
# 9       14   96                                  of   87     85
# 10      14   96                               india   93     88
# 11      46   91              seosrikantht@gmail.com  116     94
# 12      30   92                          thathineni  127    117
# 13      32   96                            srikanth  136    128
# 14      25   96                           insurance  146    137
# 15      25   96                             advisor  154    147
# 20      30   96                                life  183    179
# 21      32   96                           insurance  193    184
# 22      32   96                         corporation  205    194
# 23      32   94                                  of  208    206
# 24      30   94                               india  214    209
# 40      27   86  lictsrikant8099948528.blogspot.in,  340    306
# 41      27   86   interviewsinhyderabad.blogspot.in  374    341
#
#                                 token  label  group  right  bottom
# 1                          8099948528  PHONE      1   1025      81
# 3                          8466045457  PHONE      1   1019     138
# 5               lictsrikant@gmail.com  EMAIL      2   1025     167
# 6                                life    ORG      3     79     184
# 7                           insurance    ORG      3    176     193
# 8                         corporation    ORG      3    300     184
# 9                                  of    ORG      3    326     184
# 10                              india    ORG      3    374     184
# 11             seosrikantht@gmail.com  EMAIL      4   1025     209
# 12                         thathineni   NAME      5    542     258
# 13                           srikanth   NAME      5    755     259
# 14                          insurance    DES      6    546     296
# 15                            advisor    DES      6    669     296
# 20                               life    ORG      7    130     426
# 21                          insurance    ORG      7    381     427
# 22                        corporation    ORG      7    691     427
# 23                                 of    ORG      7    759     427
# 24                              india    ORG      7    882     426
# 40  lictsrikant8099948528.blogspot.in    WEB      8    476     533
# 41  interviewsinhyderabad.blogspot.in    WEB      8    917     533

# %%
# tagging: grouby group
col_group = ['left', 'top', 'right', 'bottom', 'label', 'token', 'group']
group_tag_img = bb_df[col_group].groupby(by='group')

# %%
img_tagging = group_tag_img.agg({
    'left':min,
    'right':max,
    'top':min,
    'bottom':max,
    'label':np.unique,
    'token':lambda x: " ".join(x)
})

# %%
img_tagging
# Out:
#        left  right  top  bottom    label  \
# group
# 1       822   1025   53     138  [PHONE]
# 2       709   1025  136     167  [EMAIL]
# 3        46    374  151     193    [ORG]
# 4       668   1025  163     209  [EMAIL]
# 5       310    755  227     259   [NAME]
# 6       399    669  271     296    [DES]
# 7        47    882  395     427    [ORG]
# 8        46    917  506     533    [WEB]
#
#                                                    token
# group
# 1                                  8099948528 8466045457
# 2                                  lictsrikant@gmail.com
# 3                    life insurance corporation of india
# 4                                 seosrikantht@gmail.com
# 5                                    thathineni srikanth
# 6                                      insurance advisor
# 7                    life insurance corporation of india
# 8      lictsrikant8099948528.blogspot.in interviewsin...

# %%
img_bb = image.copy()
for l,r,t,b,label,token in img_tagging.values:
    cv2.rectangle(img_bb,(l,t),(r,b),(0,255,0),2)
    
    cv2.putText(img_bb,str(label),(l,t),cv2.FONT_HERSHEY_PLAIN,1,(255,0,255), 2)

PIL.Image.fromarray(img_bb)
# Out:
# <PIL.Image.Image image mode=RGB size=1065x616>

# %% [markdown]
# ## Parser

# %%
def parser(text, label):
    if label == 'PHONE':
        text = text.lower()
        text = re.sub(r'\D','',text)
        
    elif label == 'EMAIL':
        text = text.lower()
        allow_special_char = '@_.\-'
        text = re.sub(r'[^A-Za-z0-9{} ]'.format(allow_special_char),'',text)
        
    elif label == 'WEB':
        text = text.lower()
        allow_special_char = ':/.%#\-'
        text = re.sub(r'[^A-Za-z{} ]'.format(allow_special_char),'',text)
        
    elif label in ('NAME', 'DES'):
        text = text.lower()
        text = re.sub(r'[^a-z ]','',text)
        text = text.title()
    
    elif label == 'ORG':
        text = text.lower()
        text = re.sub(r'[^a-z0-9 ]','',text)
        text = text.title()
    
    return text

# %%
parser('Andre)&#$@GMAIL.COM', 'EMAIL')
# Out:
# 'andre@gmail.com'

# %% [markdown]
# ## Entities

# %%
info_array = dataframe_info[['token', 'label']].values
entities = dict(NAME=[],ORG=[],DES=[],PHONE=[],EMAIL=[],WEB=[])
previus = 'O'

for token, label in info_array:
    bio_tag = label[0]
    label_tag = label[2:]
    
    # step -1 parse the token
    text = parser(token, label_tag)
    
    if bio_tag in ('B', 'I'):
        
        if previus != label_tag:
            entities[label_tag].append(text)
        else:
            if bio_tag == "B":
                entities[label_tag].append(text)
            
            else:
                if label_tag in ("NAME", "ORG", "DES"):
                    entities[label_tag][-1] = entities[label_tag][-1] + " " + text
                
                else:
                    entities[label_tag][-1] = entities[label_tag][-1] + text
    previus = label_tag

# %%
entities
# Out:
# {'NAME': ['Thathineni Srikanth'],
#  'ORG': ['Life Insurance Corporation Of India',
#   'Life Insurance Corporation Of India'],
#  'DES': ['Insurance Advisor'],
#  'PHONE': ['8099948528', '8466045457'],
#  'EMAIL': ['lictsrikant@gmail.com', 'seosrikantht@gmail.com'],
#  'WEB': ['lictsrikant.blogspot.in', 'interviewsinhyderabad.blogspot.in']}
