# %%
import cv2
import predictions as pred
import PIL

# %%
img = cv2.imread('./data/242.jpeg')

# %%
img_results, entities = pred.getPredictions(img)
# Out:
# /home/andre-pereira/projects/data_science/ner_ocr_project/1_BusinessCardNER/predictions.py:112: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['end'] = df_clean['text'].apply(lambda x: len(x)+1).cumsum() -1
# /home/andre-pereira/projects/data_science/ner_ocr_project/1_BusinessCardNER/predictions.py:113: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['start'] = df_clean[['text', 'end']].apply(lambda x: x[1] - len(x[0]), axis=1)
# /home/andre-pereira/projects/data_science/ner_ocr_project/1_BusinessCardNER/predictions.py:127: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bb_df['label'] = bb_df['label'].apply(lambda x: x[2:])
# /home/andre-pereira/projects/data_science/ner_ocr_project/1_BusinessCardNER/predictions.py:128: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bb_df['group'] = bb_df['label'].apply(grp_gen.getgroup)
# /home/andre-pereira/projects/data_science/ner_ocr_project/1_BusinessCardNER/predictions.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bb_df[['left', 'top', 'width', 'height']] = bb_df[['left', 'top', 'width', 'height']].astype(int)
# /home/andre-pereira/projects/data_science/ner_ocr_project/1_BusinessCardNER/predictions.py:133: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bb_df['right'] = bb_df['left'] + bb_df['width']
# /home/andre-pereira/projects/data_science/ner_ocr_project/1_BusinessCardNER/predictions.py:134: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bb_df['bottom'] = bb_df['top'] + bb_df['height']

# %%
entities
# Out:
# {'NAME': ['Dr T S Reddy'],
#  'ORG': ['Lea Associates South Asia Pvt Ltd'],
#  'DES': ['Senior Consultant'],
#  'PHONE': ['91', '66747135', '9182230'],
#  'EMAIL': ['tsr@lasaindia.com', 'limmappagari@ymait.com'],
#  'WEB': ['www.lasaindia.com']}

# %%
PIL.Image.fromarray(img_results)
# Out:
# <PIL.Image.Image image mode=RGB size=2440x1424>

# %%
img = cv2.imread('./data/54.jpg')

# %%
img_results, entities = pred.getPredictions(img)
# Out:
# /home/andre-pereira/projects/data_science/ner_ocr_project/1_BusinessCardNER/predictions.py:112: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['end'] = df_clean['text'].apply(lambda x: len(x)+1).cumsum() -1
# /home/andre-pereira/projects/data_science/ner_ocr_project/1_BusinessCardNER/predictions.py:113: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['start'] = df_clean[['text', 'end']].apply(lambda x: x[1] - len(x[0]), axis=1)
# /home/andre-pereira/projects/data_science/ner_ocr_project/1_BusinessCardNER/predictions.py:127: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bb_df['label'] = bb_df['label'].apply(lambda x: x[2:])
# /home/andre-pereira/projects/data_science/ner_ocr_project/1_BusinessCardNER/predictions.py:128: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bb_df['group'] = bb_df['label'].apply(grp_gen.getgroup)
# /home/andre-pereira/projects/data_science/ner_ocr_project/1_BusinessCardNER/predictions.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bb_df[['left', 'top', 'width', 'height']] = bb_df[['left', 'top', 'width', 'height']].astype(int)
# /home/andre-pereira/projects/data_science/ner_ocr_project/1_BusinessCardNER/predictions.py:133: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bb_df['right'] = bb_df['left'] + bb_df['width']
# /home/andre-pereira/projects/data_science/ner_ocr_project/1_BusinessCardNER/predictions.py:134: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bb_df['bottom'] = bb_df['top'] + bb_df['height']

# %%
entities
# Out:
# {'NAME': ['Joseph C Wu'],
#  'ORG': ['Stanford Medicine Cardiovascular Institute'],
#  'DES': ['Director'],
#  'PHONE': ['650736'],
#  'EMAIL': ['joewu@stanford.edu'],
#  'WEB': ['http//wulab.stanford.edu', 'hetp//evistanford.edu']}

# %%
PIL.Image.fromarray(img_results)
# Out:
# <PIL.Image.Image image mode=RGB size=505x316>
